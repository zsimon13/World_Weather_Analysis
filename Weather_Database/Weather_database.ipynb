# %%
#import the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#import Time library
import time
from datetime import datetime

# %%
#create a set of random latitude and longitude combinations
lats=np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs=zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#create a list for holding the cities
cities=[]
#identify the nearest cit;y for  each latitiude and longitude combination
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the citty is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
#print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %%
#starting url from weather map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#create an empty list to hold the weather data
city_data = []
#print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters
record_count = 1 
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    #group cities intosets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        recrd_count =1
        time.sleep(60)
        
    #create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #log the url, record and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #add 1 to the record count
    record_count +=1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vierzon
# Processing Record 2 of Set 1 | nyaunglebin
# Processing Record 3 of Set 1 | kimbe
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | mnogovershinnyy
# Processing Record 6 of Set 1 | abu jubayhah
# City not found. Skipping...
# Processing Record 7 of Set 1 | great yarmouth
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | benemerito de las americas
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | grand gaube
# Processing Record 14 of Set 1 | luganville
# Processing Record 15 of Set 1 | piacabucu
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | farafangana
# Processing Record 19 of Set 1 | korla
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 1 | baoqing
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | rocha
# Processing Record 29 of Set 1 | gudalur
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | zyryanka
# Processing Record 34 of Set 1 | bengkulu
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | talnakh
# Processing Record 38 of Set 1 | xining
# Processing Record 39 of Set 1 | pisco
# Processing Record 40 of Set 1 | elat
# Processing Record 41 of Set 1 | katsuura
# Processing Record 42 of Set 1 | grindavik
# Processing Record 43 of Set 1 | sidney
# Processing Record 44 of Set 1 | sinnamary
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 1 | sur
# Processing Record 51 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 52 of Set 2 | tuatapere
# Processing Record 53 of Set 2 | punta arenas
# Processing Record 54 of Set 2 | faanui
# Processing Record 55 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 56 of Set 2 | flinders
# Processing Record 57 of Set 2 | kijang
# Processing Record 58 of Set 2 | salinas
# Processing Record 59 of Set 2 | moerai
# Processing Record 60 of Set 2 | guzelyurt
# Processing Record 61 of Set 2 | kidal
# Processing Record 62 of Set 2 | bhadasar
# Processing Record 63 of Set 2 | rikitea
# Processing Record 64 of Set 2 | kaseda
# Processing Record 65 of Set 2 | nikolskoye
# Processing Record 66 of Set 2 | acapulco
# Processing Record 67 of Set 2 | hobart
# Processing Record 68 of Set 2 | zatec
# Processing Record 69 of Set 2 | hermanus
# Processing Record 70 of Set 2 | leningradskiy
# Processing Record 71 of Set 2 | sitka
# Processing Record 72 of Set 2 | port elizabeth
# Processing Record 73 of Set 2 | bograd
# Processing Record 74 of Set 2 | agadez
# Processing Record 75 of Set 2 | nanortalik
# Processing Record 76 of Set 2 | cape town
# Processing Record 77 of Set 2 | mercedes
# Processing Record 78 of Set 2 | port keats
# Processing Record 79 of Set 2 | sao miguel do araguaia
# Processing Record 80 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 81 of Set 2 | gaogou
# Processing Record 82 of Set 2 | qaanaaq
# Processing Record 83 of Set 2 | klyuchi
# Processing Record 84 of Set 2 | bluff
# Processing Record 85 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 86 of Set 2 | vila
# Processing Record 87 of Set 2 | ola
# Processing Record 88 of Set 2 | oussouye
# Processing Record 89 of Set 2 | vaini
# Processing Record 90 of Set 2 | tilichiki
# Processing Record 91 of Set 2 | kortkeros
# Processing Record 92 of Set 2 | new norfolk
# Processing Record 93 of Set 2 | edson
# Processing Record 94 of Set 2 | ponta do sol
# Processing Record 95 of Set 2 | dalbandin
# Processing Record 96 of Set 2 | baykit
# Processing Record 97 of Set 2 | kahului
# Processing Record 98 of Set 2 | roebourne
# Processing Record 99 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 100 of Set 2 | bambous virieux
# Processing Record 101 of Set 3 | hofn
# Processing Record 102 of Set 3 | kamwenge
# Processing Record 103 of Set 3 | roura
# Processing Record 104 of Set 3 | alofi
# Processing Record 105 of Set 3 | bredasdorp
# Processing Record 106 of Set 3 | tuktoyaktuk
# Processing Record 107 of Set 3 | chokurdakh
# Processing Record 108 of Set 3 | butaritari
# Processing Record 109 of Set 3 | lavrentiya
# Processing Record 110 of Set 3 | dingle
# Processing Record 111 of Set 3 | tamandare
# Processing Record 112 of Set 3 | olafsvik
# Processing Record 113 of Set 3 | langsa
# Processing Record 114 of Set 3 | provideniya
# Processing Record 115 of Set 3 | krasnoselkup
# Processing Record 116 of Set 3 | balkanabat
# Processing Record 117 of Set 3 | hasaki
# Processing Record 118 of Set 3 | singaraja
# Processing Record 119 of Set 3 | worland
# Processing Record 120 of Set 3 | severo-kurilsk
# Processing Record 121 of Set 3 | bytca
# Processing Record 122 of Set 3 | qasigiannguit
# Processing Record 123 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 124 of Set 3 | goderich
# Processing Record 125 of Set 3 | chuy
# Processing Record 126 of Set 3 | kavieng
# Processing Record 127 of Set 3 | codajas
# Processing Record 128 of Set 3 | pouembout
# Processing Record 129 of Set 3 | kuningan
# Processing Record 130 of Set 3 | onguday
# Processing Record 131 of Set 3 | svetlyy
# Processing Record 132 of Set 3 | ambilobe
# Processing Record 133 of Set 3 | viedma
# Processing Record 134 of Set 3 | la ronge
# Processing Record 135 of Set 3 | surt
# Processing Record 136 of Set 3 | panaba
# Processing Record 137 of Set 3 | westport
# Processing Record 138 of Set 3 | lebu
# Processing Record 139 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 140 of Set 3 | bulgan
# Processing Record 141 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 142 of Set 3 | esmeraldas
# Processing Record 143 of Set 3 | honiara
# Processing Record 144 of Set 3 | shimsk
# Processing Record 145 of Set 3 | leona vicario
# Processing Record 146 of Set 3 | carutapera
# Processing Record 147 of Set 3 | ilulissat
# Processing Record 148 of Set 3 | port macquarie
# Processing Record 149 of Set 3 | namibe
# Processing Record 150 of Set 3 | were ilu
# Processing Record 151 of Set 4 | sioux lookout
# Processing Record 152 of Set 4 | charters towers
# Processing Record 153 of Set 4 | camana
# Processing Record 154 of Set 4 | beringovskiy
# Processing Record 155 of Set 4 | esperance
# Processing Record 156 of Set 4 | pochutla
# Processing Record 157 of Set 4 | san andres
# Processing Record 158 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 159 of Set 4 | ankazoabo
# Processing Record 160 of Set 4 | fallon
# Processing Record 161 of Set 4 | yellowknife
# Processing Record 162 of Set 4 | mount gambier
# Processing Record 163 of Set 4 | lewistown
# Processing Record 164 of Set 4 | thompson
# Processing Record 165 of Set 4 | half moon bay
# Processing Record 166 of Set 4 | tucupita
# Processing Record 167 of Set 4 | klaeng
# Processing Record 168 of Set 4 | nome
# Processing Record 169 of Set 4 | geraldton
# Processing Record 170 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 171 of Set 4 | sisimiut
# Processing Record 172 of Set 4 | gao
# Processing Record 173 of Set 4 | usogorsk
# Processing Record 174 of Set 4 | savinka
# Processing Record 175 of Set 4 | khomutovo
# Processing Record 176 of Set 4 | mayor pablo lagerenza
# Processing Record 177 of Set 4 | sirjan
# Processing Record 178 of Set 4 | carnarvon
# Processing Record 179 of Set 4 | urucui
# Processing Record 180 of Set 4 | luanda
# Processing Record 181 of Set 4 | avarua
# Processing Record 182 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 183 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 184 of Set 4 | ishigaki
# Processing Record 185 of Set 4 | santa maria
# Processing Record 186 of Set 4 | hovd
# Processing Record 187 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 188 of Set 4 | nador
# Processing Record 189 of Set 4 | vestmannaeyjar
# Processing Record 190 of Set 4 | luderitz
# Processing Record 191 of Set 4 | hamilton
# Processing Record 192 of Set 4 | ozinki
# Processing Record 193 of Set 4 | buluang
# Processing Record 194 of Set 4 | port moresby
# Processing Record 195 of Set 4 | broome
# Processing Record 196 of Set 4 | victoria
# Processing Record 197 of Set 4 | vanavara
# Processing Record 198 of Set 4 | mahebourg
# Processing Record 199 of Set 4 | blackwater
# Processing Record 200 of Set 4 | turbat
# Processing Record 201 of Set 5 | ribeira grande
# Processing Record 202 of Set 5 | bongandanga
# Processing Record 203 of Set 5 | atbasar
# Processing Record 204 of Set 5 | locri
# Processing Record 205 of Set 5 | linapacan
# City not found. Skipping...
# Processing Record 206 of Set 5 | matagami
# Processing Record 207 of Set 5 | iqaluit
# Processing Record 208 of Set 5 | nyurba
# Processing Record 209 of Set 5 | honningsvag
# Processing Record 210 of Set 5 | kieta
# Processing Record 211 of Set 5 | saldanha
# Processing Record 212 of Set 5 | dustlik
# Processing Record 213 of Set 5 | sao joao da barra
# Processing Record 214 of Set 5 | kodiak
# Processing Record 215 of Set 5 | tiksi
# Processing Record 216 of Set 5 | hambantota
# Processing Record 217 of Set 5 | souillac
# Processing Record 218 of Set 5 | doraha
# Processing Record 219 of Set 5 | sulangan
# Processing Record 220 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 221 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 222 of Set 5 | corn island
# Processing Record 223 of Set 5 | kutulik
# Processing Record 224 of Set 5 | uk
# City not found. Skipping...
# Processing Record 225 of Set 5 | cape canaveral
# Processing Record 226 of Set 5 | kemin
# Processing Record 227 of Set 5 | georgetown
# Processing Record 228 of Set 5 | launceston
# Processing Record 229 of Set 5 | port lincoln
# Processing Record 230 of Set 5 | plettenberg bay
# Processing Record 231 of Set 5 | constitucion
# Processing Record 232 of Set 5 | laguna
# Processing Record 233 of Set 5 | port arthur
# Processing Record 234 of Set 5 | okha
# Processing Record 235 of Set 5 | galapagar
# Processing Record 236 of Set 5 | iki-burul
# Processing Record 237 of Set 5 | ndele
# Processing Record 238 of Set 5 | bandipur
# Processing Record 239 of Set 5 | sadat
# Processing Record 240 of Set 5 | thongwa
# Processing Record 241 of Set 5 | stephenville
# Processing Record 242 of Set 5 | acajutla
# Processing Record 243 of Set 5 | middle island
# Processing Record 244 of Set 5 | sao filipe
# Processing Record 245 of Set 5 | lufilufi
# Processing Record 246 of Set 5 | saskylakh
# Processing Record 247 of Set 5 | tasiilaq
# Processing Record 248 of Set 5 | fuerte olimpo
# Processing Record 249 of Set 5 | tahta
# Processing Record 250 of Set 5 | arraial do cabo
# Processing Record 251 of Set 6 | kenai
# Processing Record 252 of Set 6 | pangnirtung
# Processing Record 253 of Set 6 | port blair
# Processing Record 254 of Set 6 | klaksvik
# Processing Record 255 of Set 6 | morro bay
# Processing Record 256 of Set 6 | parang
# Processing Record 257 of Set 6 | venice
# Processing Record 258 of Set 6 | kavaratti
# Processing Record 259 of Set 6 | san cristobal
# Processing Record 260 of Set 6 | kautokeino
# Processing Record 261 of Set 6 | port hawkesbury
# Processing Record 262 of Set 6 | sucua
# Processing Record 263 of Set 6 | kerema
# Processing Record 264 of Set 6 | coxim
# Processing Record 265 of Set 6 | puerto madryn
# Processing Record 266 of Set 6 | subiaco
# Processing Record 267 of Set 6 | mahibadhoo
# Processing Record 268 of Set 6 | dondaicha
# Processing Record 269 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 270 of Set 6 | richards bay
# Processing Record 271 of Set 6 | burnie
# Processing Record 272 of Set 6 | mayo
# Processing Record 273 of Set 6 | waingapu
# Processing Record 274 of Set 6 | hobyo
# Processing Record 275 of Set 6 | cidreira
# Processing Record 276 of Set 6 | pinega
# Processing Record 277 of Set 6 | coquimbo
# Processing Record 278 of Set 6 | manta
# Processing Record 279 of Set 6 | airai
# Processing Record 280 of Set 6 | egvekinot
# Processing Record 281 of Set 6 | salto
# Processing Record 282 of Set 6 | isangel
# Processing Record 283 of Set 6 | bandundu
# Processing Record 284 of Set 6 | conakry
# Processing Record 285 of Set 6 | codrington
# Processing Record 286 of Set 6 | marzuq
# Processing Record 287 of Set 6 | boa vista
# Processing Record 288 of Set 6 | brae
# Processing Record 289 of Set 6 | kurilsk
# Processing Record 290 of Set 6 | pozo colorado
# Processing Record 291 of Set 6 | batemans bay
# Processing Record 292 of Set 6 | vao
# Processing Record 293 of Set 6 | bandarbeyla
# Processing Record 294 of Set 6 | panalingaan
# Processing Record 295 of Set 6 | fort nelson
# Processing Record 296 of Set 6 | cabo san lucas
# Processing Record 297 of Set 6 | grenaa
# Processing Record 298 of Set 6 | maningrida
# Processing Record 299 of Set 6 | lanigan
# Processing Record 300 of Set 6 | zhigansk
# Processing Record 301 of Set 7 | haines junction
# Processing Record 302 of Set 7 | mar del plata
# Processing Record 303 of Set 7 | yumen
# Processing Record 304 of Set 7 | lompoc
# Processing Record 305 of Set 7 | smithers
# Processing Record 306 of Set 7 | aklavik
# Processing Record 307 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 308 of Set 7 | narsaq
# Processing Record 309 of Set 7 | srednekolymsk
# Processing Record 310 of Set 7 | wanning
# Processing Record 311 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 312 of Set 7 | maarianhamina
# Processing Record 313 of Set 7 | jumla
# Processing Record 314 of Set 7 | juneau
# Processing Record 315 of Set 7 | hammerfest
# Processing Record 316 of Set 7 | corinto
# Processing Record 317 of Set 7 | cap malheureux
# Processing Record 318 of Set 7 | gombong
# Processing Record 319 of Set 7 | gull lake
# Processing Record 320 of Set 7 | motala
# Processing Record 321 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 322 of Set 7 | kupang
# Processing Record 323 of Set 7 | hohhot
# Processing Record 324 of Set 7 | ondjiva
# Processing Record 325 of Set 7 | umm kaddadah
# Processing Record 326 of Set 7 | gillette
# Processing Record 327 of Set 7 | cayenne
# Processing Record 328 of Set 7 | pimenta bueno
# Processing Record 329 of Set 7 | champerico
# Processing Record 330 of Set 7 | esqueda
# Processing Record 331 of Set 7 | turukhansk
# Processing Record 332 of Set 7 | sao francisco de assis
# Processing Record 333 of Set 7 | mengcheng
# Processing Record 334 of Set 7 | burley
# Processing Record 335 of Set 7 | duluth
# Processing Record 336 of Set 7 | bourail
# Processing Record 337 of Set 7 | aransas pass
# Processing Record 338 of Set 7 | ahipara
# Processing Record 339 of Set 7 | mayskiy
# Processing Record 340 of Set 7 | lensk
# Processing Record 341 of Set 7 | nantucket
# Processing Record 342 of Set 7 | mezhdurechensk
# Processing Record 343 of Set 7 | varhaug
# Processing Record 344 of Set 7 | bungoma
# Processing Record 345 of Set 7 | ust-kuyga
# Processing Record 346 of Set 7 | yajalon
# Processing Record 347 of Set 7 | bilma
# Processing Record 348 of Set 7 | pusztaszabolcs
# Processing Record 349 of Set 7 | tuy hoa
# Processing Record 350 of Set 7 | rawson
# Processing Record 351 of Set 8 | karratha
# Processing Record 352 of Set 8 | atar
# Processing Record 353 of Set 8 | sembe
# Processing Record 354 of Set 8 | parga
# Processing Record 355 of Set 8 | bellavista
# Processing Record 356 of Set 8 | peterhead
# Processing Record 357 of Set 8 | moundou
# Processing Record 358 of Set 8 | okhotsk
# Processing Record 359 of Set 8 | matadi
# Processing Record 360 of Set 8 | general roca
# Processing Record 361 of Set 8 | mae sot
# Processing Record 362 of Set 8 | bud
# Processing Record 363 of Set 8 | opuwo
# Processing Record 364 of Set 8 | lata
# Processing Record 365 of Set 8 | port hedland
# Processing Record 366 of Set 8 | matara
# Processing Record 367 of Set 8 | veraval
# Processing Record 368 of Set 8 | tura
# Processing Record 369 of Set 8 | luangwa
# Processing Record 370 of Set 8 | west richland
# Processing Record 371 of Set 8 | alekseyevskaya
# Processing Record 372 of Set 8 | tezu
# Processing Record 373 of Set 8 | arona
# Processing Record 374 of Set 8 | cherskiy
# Processing Record 375 of Set 8 | sakaiminato
# Processing Record 376 of Set 8 | lixourion
# Processing Record 377 of Set 8 | mirador
# Processing Record 378 of Set 8 | wesselsbron
# Processing Record 379 of Set 8 | coihueco
# Processing Record 380 of Set 8 | coro
# Processing Record 381 of Set 8 | pires do rio
# Processing Record 382 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 383 of Set 8 | gander
# Processing Record 384 of Set 8 | tsogni
# Processing Record 385 of Set 8 | touros
# Processing Record 386 of Set 8 | bilibino
# Processing Record 387 of Set 8 | sri aman
# Processing Record 388 of Set 8 | lodwar
# Processing Record 389 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 390 of Set 8 | linares
# Processing Record 391 of Set 8 | gigmoto
# Processing Record 392 of Set 8 | pouebo
# Processing Record 393 of Set 8 | vung tau
# Processing Record 394 of Set 8 | gorontalo
# Processing Record 395 of Set 8 | manalurpet
# City not found. Skipping...
# Processing Record 396 of Set 8 | longyearbyen
# Processing Record 397 of Set 8 | hudson bay
# Processing Record 398 of Set 8 | buraydah
# Processing Record 399 of Set 8 | ponta delgada
# Processing Record 400 of Set 8 | letterkenny
# Processing Record 401 of Set 9 | broken hill
# Processing Record 402 of Set 9 | bermeo
# Processing Record 403 of Set 9 | pacific grove
# Processing Record 404 of Set 9 | waspan
# Processing Record 405 of Set 9 | dedougou
# Processing Record 406 of Set 9 | ketchikan
# Processing Record 407 of Set 9 | fortuna
# Processing Record 408 of Set 9 | ostrovnoy
# Processing Record 409 of Set 9 | zaranj
# Processing Record 410 of Set 9 | marsta
# Processing Record 411 of Set 9 | gat
# Processing Record 412 of Set 9 | neuquen
# Processing Record 413 of Set 9 | puerto penasco
# Processing Record 414 of Set 9 | loikaw
# Processing Record 415 of Set 9 | kirakira
# Processing Record 416 of Set 9 | tambacounda
# Processing Record 417 of Set 9 | vardo
# Processing Record 418 of Set 9 | maldonado
# Processing Record 419 of Set 9 | ambad
# Processing Record 420 of Set 9 | arica
# Processing Record 421 of Set 9 | goryachegorsk
# Processing Record 422 of Set 9 | trinidad
# Processing Record 423 of Set 9 | baijiantan
# Processing Record 424 of Set 9 | sola
# Processing Record 425 of Set 9 | biak
# Processing Record 426 of Set 9 | paamiut
# Processing Record 427 of Set 9 | pamplona
# Processing Record 428 of Set 9 | faya
# Processing Record 429 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 430 of Set 9 | praia
# Processing Record 431 of Set 9 | margate
# Processing Record 432 of Set 9 | yulara
# Processing Record 433 of Set 9 | prior lake
# Processing Record 434 of Set 9 | kungurtug
# Processing Record 435 of Set 9 | pevek
# Processing Record 436 of Set 9 | havoysund
# Processing Record 437 of Set 9 | safaga
# Processing Record 438 of Set 9 | yenagoa
# Processing Record 439 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 440 of Set 9 | shancheng
# Processing Record 441 of Set 9 | glenwood springs
# Processing Record 442 of Set 9 | shouguang
# Processing Record 443 of Set 9 | xai-xai
# Processing Record 444 of Set 9 | hue
# Processing Record 445 of Set 9 | clyde river
# Processing Record 446 of Set 9 | salinopolis
# Processing Record 447 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 448 of Set 9 | yarega
# Processing Record 449 of Set 9 | wahpeton
# Processing Record 450 of Set 9 | amarkantak
# Processing Record 451 of Set 10 | lorengau
# Processing Record 452 of Set 10 | chicama
# Processing Record 453 of Set 10 | caxito
# Processing Record 454 of Set 10 | pavilosta
# Processing Record 455 of Set 10 | ulladulla
# Processing Record 456 of Set 10 | shimoda
# Processing Record 457 of Set 10 | palafrugell
# Processing Record 458 of Set 10 | olawa
# Processing Record 459 of Set 10 | chalisgaon
# Processing Record 460 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 461 of Set 10 | ancud
# Processing Record 462 of Set 10 | kruisfontein
# Processing Record 463 of Set 10 | novikovo
# Processing Record 464 of Set 10 | campina grande
# Processing Record 465 of Set 10 | koygorodok
# Processing Record 466 of Set 10 | pitea
# Processing Record 467 of Set 10 | lahaina
# Processing Record 468 of Set 10 | wattegama
# Processing Record 469 of Set 10 | canyon
# Processing Record 470 of Set 10 | yunhe
# Processing Record 471 of Set 10 | husavik
# Processing Record 472 of Set 10 | yarada
# Processing Record 473 of Set 10 | kailua
# Processing Record 474 of Set 10 | graaff-reinet
# Processing Record 475 of Set 10 | siniscola
# Processing Record 476 of Set 10 | los llanos de aridane
# Processing Record 477 of Set 10 | progreso
# Processing Record 478 of Set 10 | shemonaikha
# Processing Record 479 of Set 10 | abu samrah
# Processing Record 480 of Set 10 | winton
# Processing Record 481 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 482 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 483 of Set 10 | aiken
# Processing Record 484 of Set 10 | muromtsevo
# Processing Record 485 of Set 10 | nemuro
# Processing Record 486 of Set 10 | lasa
# Processing Record 487 of Set 10 | seydi
# Processing Record 488 of Set 10 | filotion
# Processing Record 489 of Set 10 | salalah
# Processing Record 490 of Set 10 | lagoa
# Processing Record 491 of Set 10 | kasungu
# Processing Record 492 of Set 10 | evensk
# Processing Record 493 of Set 10 | hazorasp
# Processing Record 494 of Set 10 | conceicao do araguaia
# Processing Record 495 of Set 10 | stornoway
# Processing Record 496 of Set 10 | atakpame
# Processing Record 497 of Set 10 | camacha
# Processing Record 498 of Set 10 | aktash
# Processing Record 499 of Set 10 | tautira
# Processing Record 500 of Set 10 | hami
# Processing Record 501 of Set 11 | quepos
# Processing Record 502 of Set 11 | trang
# Processing Record 503 of Set 11 | maruim
# Processing Record 504 of Set 11 | balsas
# Processing Record 505 of Set 11 | bereda
# Processing Record 506 of Set 11 | torbay
# Processing Record 507 of Set 11 | asau
# Processing Record 508 of Set 11 | mancheral
# Processing Record 509 of Set 11 | tupik
# Processing Record 510 of Set 11 | coihaique
# Processing Record 511 of Set 11 | kununurra
# Processing Record 512 of Set 11 | cairns
# Processing Record 513 of Set 11 | wajid
# Processing Record 514 of Set 11 | konyshevka
# Processing Record 515 of Set 11 | sumenep
# Processing Record 516 of Set 11 | kiruna
# Processing Record 517 of Set 11 | maunabo
# Processing Record 518 of Set 11 | san pedro de uraba
# Processing Record 519 of Set 11 | guarumal
# Processing Record 520 of Set 11 | brigantine
# Processing Record 521 of Set 11 | mao
# Processing Record 522 of Set 11 | hurghada
# Processing Record 523 of Set 11 | high level
# Processing Record 524 of Set 11 | sarszentmihaly
# Processing Record 525 of Set 11 | solnechnyy
# Processing Record 526 of Set 11 | shalya
# Processing Record 527 of Set 11 | kyra
# Processing Record 528 of Set 11 | ivolginsk
# Processing Record 529 of Set 11 | brewster
# Processing Record 530 of Set 11 | paro
# Processing Record 531 of Set 11 | bremervorde
# Processing Record 532 of Set 11 | monywa
# Processing Record 533 of Set 11 | poselki
# Processing Record 534 of Set 11 | fort payne
# Processing Record 535 of Set 11 | ajdabiya
# Processing Record 536 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 537 of Set 11 | la seyne-sur-mer
# Processing Record 538 of Set 11 | caxias
# Processing Record 539 of Set 11 | tual
# Processing Record 540 of Set 11 | dzilam gonzalez
# Processing Record 541 of Set 11 | idah
# Processing Record 542 of Set 11 | tonekabon
# Processing Record 543 of Set 11 | la crosse
# Processing Record 544 of Set 11 | raga
# Processing Record 545 of Set 11 | vila franca do campo
# Processing Record 546 of Set 11 | kutum
# Processing Record 547 of Set 11 | hit
# Processing Record 548 of Set 11 | qazanbulaq
# Processing Record 549 of Set 11 | vozdvizhenka
# Processing Record 550 of Set 11 | lazaro cardenas
# Processing Record 551 of Set 12 | ginda
# Processing Record 552 of Set 12 | zhanaozen
# Processing Record 553 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 554 of Set 12 | malakal
# Processing Record 555 of Set 12 | hanzhong
# Processing Record 556 of Set 12 | jauja
# Processing Record 557 of Set 12 | reconquista
# Processing Record 558 of Set 12 | horn
# Processing Record 559 of Set 12 | portland
# Processing Record 560 of Set 12 | inhambane
# Processing Record 561 of Set 12 | itaituba
# Processing Record 562 of Set 12 | marawi
# Processing Record 563 of Set 12 | liepaja
# Processing Record 564 of Set 12 | banda aceh
# Processing Record 565 of Set 12 | masvingo
# Processing Record 566 of Set 12 | bara
# Processing Record 567 of Set 12 | santiago del estero
# Processing Record 568 of Set 12 | taoudenni
# Processing Record 569 of Set 12 | gudur
# Processing Record 570 of Set 12 | bocaranga
# City not found. Skipping...
# Processing Record 571 of Set 12 | tomatlan
# Processing Record 572 of Set 12 | verkhnetulomskiy
# Processing Record 573 of Set 12 | camiri
# Processing Record 574 of Set 12 | verkhnevilyuysk
# Processing Record 575 of Set 12 | mareeba
# Processing Record 576 of Set 12 | udachnyy
# Processing Record 577 of Set 12 | tevriz
# Processing Record 578 of Set 12 | zhangye
# Processing Record 579 of Set 12 | boundiali
# Processing Record 580 of Set 12 | dukat
# Processing Record 581 of Set 12 | nelson bay
# Processing Record 582 of Set 12 | canico
# Processing Record 583 of Set 12 | bairiki
# Processing Record 584 of Set 12 | frankfort
# Processing Record 585 of Set 12 | thinadhoo
# Processing Record 586 of Set 12 | rockland
# Processing Record 587 of Set 12 | hailey
# Processing Record 588 of Set 12 | ballina
# Processing Record 589 of Set 12 | itarema
# Processing Record 590 of Set 12 | aksarka
# Processing Record 591 of Set 12 | lukovetskiy
# Processing Record 592 of Set 12 | vallenar
# Processing Record 593 of Set 12 | kuandian
# Processing Record 594 of Set 12 | oktyabrskoye
# Processing Record 595 of Set 12 | spring hill
# Processing Record 596 of Set 12 | nichinan
# Processing Record 597 of Set 12 | saint-francois
# Processing Record 598 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 599 of Set 12 | lander
# Processing Record 600 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 601 of Set 13 | sao gotardo
# Processing Record 602 of Set 13 | birao
# Processing Record 603 of Set 13 | gushikawa
# Processing Record 604 of Set 13 | vigrestad
# Processing Record 605 of Set 13 | igarka
# Processing Record 606 of Set 13 | tianpeng
# Processing Record 607 of Set 13 | oistins
# Processing Record 608 of Set 13 | ewa beach
# Processing Record 609 of Set 13 | suluq
# Processing Record 610 of Set 13 | tahe
# Processing Record 611 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 612 of Set 13 | hay river
# Processing Record 613 of Set 13 | leander
# Processing Record 614 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 615 of Set 13 | butia
# Processing Record 616 of Set 13 | rupert
# Processing Record 617 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 618 of Set 13 | acarau
# Processing Record 619 of Set 13 | prince albert
# Processing Record 620 of Set 13 | san carlos de bariloche
# Processing Record 621 of Set 13 | gumusyaka
# City not found. Skipping...
# Processing Record 622 of Set 13 | teya
# Processing Record 623 of Set 13 | nsanje
# Processing Record 624 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 625 of Set 13 | do gonbadan
# Processing Record 626 of Set 13 | nago
# Processing Record 627 of Set 13 | pramanta
# Processing Record 628 of Set 13 | marfino
# Processing Record 629 of Set 13 | san ramon
# Processing Record 630 of Set 13 | lingao
# Processing Record 631 of Set 13 | meulaboh
# Processing Record 632 of Set 13 | khandyga
# Processing Record 633 of Set 13 | santa luzia
# Processing Record 634 of Set 13 | kaeo
# Processing Record 635 of Set 13 | avera
# Processing Record 636 of Set 13 | nouadhibou
# Processing Record 637 of Set 13 | billings
# Processing Record 638 of Set 13 | shaunavon
# Processing Record 639 of Set 13 | boulder
# Processing Record 640 of Set 13 | aksu
# Processing Record 641 of Set 13 | joshimath
# Processing Record 642 of Set 13 | kamen-rybolov
# Processing Record 643 of Set 13 | cockburn town
# Processing Record 644 of Set 13 | san jose de guanipa
# Processing Record 645 of Set 13 | graham
# Processing Record 646 of Set 13 | aasiaat
# Processing Record 647 of Set 13 | vilyuysk
# Processing Record 648 of Set 13 | mastic beach
# Processing Record 649 of Set 13 | panji
# Processing Record 650 of Set 13 | kralendijk
# Processing Record 651 of Set 14 | gejiu
# Processing Record 652 of Set 14 | prainha
# Processing Record 653 of Set 14 | ukiah
# Processing Record 654 of Set 14 | labuhan
# Processing Record 655 of Set 14 | bubaque
# Processing Record 656 of Set 14 | bell ville
# Processing Record 657 of Set 14 | sao jose da coroa grande
# Processing Record 658 of Set 14 | west wendover
# Processing Record 659 of Set 14 | batagay
# Processing Record 660 of Set 14 | zhuanghe
# Processing Record 661 of Set 14 | mpika
# Processing Record 662 of Set 14 | bayan
# Processing Record 663 of Set 14 | villazon
# Processing Record 664 of Set 14 | hualmay
# Processing Record 665 of Set 14 | bonavista
# Processing Record 666 of Set 14 | pak phanang
# Processing Record 667 of Set 14 | andenes
# Processing Record 668 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 669 of Set 14 | tateyama
# Processing Record 670 of Set 14 | benghazi
# Processing Record 671 of Set 14 | sechura
# Processing Record 672 of Set 14 | havre-saint-pierre
# Processing Record 673 of Set 14 | soure
# Processing Record 674 of Set 14 | turayf
# Processing Record 675 of Set 14 | wanaka
# Processing Record 676 of Set 14 | baglung
# Processing Record 677 of Set 14 | eureka
# Processing Record 678 of Set 14 | saint-joseph
# Processing Record 679 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 680 of Set 14 | waldshut-tiengen
# Processing Record 681 of Set 14 | mandera
# Processing Record 682 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 683 of Set 14 | ust-tsilma
# Processing Record 684 of Set 14 | kardamas
# Processing Record 685 of Set 14 | puerto colombia
# Processing Record 686 of Set 14 | roma
# Processing Record 687 of Set 14 | poum
# Processing Record 688 of Set 14 | canberra
# Processing Record 689 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 690 of Set 14 | teahupoo
# Processing Record 691 of Set 14 | leticia
# Processing Record 692 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 693 of Set 14 | krasnyy chikoy
# Processing Record 694 of Set 14 | praia da vitoria
# Processing Record 695 of Set 14 | abu zabad
# Processing Record 696 of Set 14 | ust-kulom
# Processing Record 697 of Set 14 | vostok
# Processing Record 698 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 699 of Set 14 | huarmey
# Processing Record 700 of Set 14 | priiskovyy
# Processing Record 701 of Set 15 | zhovtneve
# Processing Record 702 of Set 15 | jardim
# Processing Record 703 of Set 15 | pathein
# Processing Record 704 of Set 15 | naryan-mar
# Processing Record 705 of Set 15 | makarov
# Processing Record 706 of Set 15 | nabire
# Processing Record 707 of Set 15 | makat
# Processing Record 708 of Set 15 | toamasina
# Processing Record 709 of Set 15 | kemi
# Processing Record 710 of Set 15 | tastur
# Processing Record 711 of Set 15 | shakhtinsk
# Processing Record 712 of Set 15 | tinskoy
# Processing Record 713 of Set 15 | farsund
# Processing Record 714 of Set 15 | anadyr
# Processing Record 715 of Set 15 | arlit
# Processing Record 716 of Set 15 | rudbar
# Processing Record 717 of Set 15 | kaitangata
# Processing Record 718 of Set 15 | teknaf
# Processing Record 719 of Set 15 | linhares
# Processing Record 720 of Set 15 | doka
# Processing Record 721 of Set 15 | berdigestyakh
# Processing Record 722 of Set 15 | limin khersonisou
# Processing Record 723 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 724 of Set 15 | emirdag
# Processing Record 725 of Set 15 | chapais
# Processing Record 726 of Set 15 | vila velha
# Processing Record 727 of Set 15 | marsa matruh
# Processing Record 728 of Set 15 | maragogi
# Processing Record 729 of Set 15 | genthin
# Processing Record 730 of Set 15 | kasempa
# Processing Record 731 of Set 15 | iskateley
# Processing Record 732 of Set 15 | ayan
# Processing Record 733 of Set 15 | aban
# Processing Record 734 of Set 15 | teguldet
# Processing Record 735 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 736 of Set 15 | pierre
# Processing Record 737 of Set 15 | bodo
# Processing Record 738 of Set 15 | norman wells
# Processing Record 739 of Set 15 | novorudnyy
# Processing Record 740 of Set 15 | naze
# Processing Record 741 of Set 15 | capreol
# Processing Record 742 of Set 15 | paragominas
# Processing Record 743 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 744 of Set 15 | beidao
# Processing Record 745 of Set 15 | aitape
# Processing Record 746 of Set 15 | lipin bor
# Processing Record 747 of Set 15 | tzaneen
# Processing Record 748 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 749 of Set 15 | fenyi
# Processing Record 750 of Set 15 | bogorodskoye
# Processing Record 751 of Set 16 | verkhnyaya inta
# Processing Record 752 of Set 16 | rawannawi
# City not found. Skipping...
# Processing Record 753 of Set 16 | bozoum
# Processing Record 754 of Set 16 | aswan
# Processing Record 755 of Set 16 | port-cartier
# Processing Record 756 of Set 16 | chumikan
# Processing Record 757 of Set 16 | franklin
# Processing Record 758 of Set 16 | prata
# Processing Record 759 of Set 16 | hvide sande
# Processing Record 760 of Set 16 | jalalpur pirwala
# Processing Record 761 of Set 16 | dubai
# Processing Record 762 of Set 16 | botou
# Processing Record 763 of Set 16 | miranda
# Processing Record 764 of Set 16 | rio grande
# Processing Record 765 of Set 16 | garissa
# Processing Record 766 of Set 16 | puerto escondido
# Processing Record 767 of Set 16 | udankudi
# Processing Record 768 of Set 16 | berlevag
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 713

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# 0                     Vierzon  47.2101    2.0625     64.99        56
# 1                 Nyaunglebin  17.9500   96.7333     75.72        95
# 2                       Kimbe  -5.5502  150.1429     74.59        92
# 3                 Port Alfred -33.5906   26.8910     59.94        43
# 4             Mnogovershinnyy  53.9353  139.9242     49.06        82
# 5              Great Yarmouth  52.6083    1.7305     54.01        73
# 6                    Khatanga  71.9667  102.5000     29.43        84
# 7                      Albany  42.6001  -73.9662     89.17        47
# 8  Benemerito De Las Americas  16.5167  -90.6439     90.95        48
# 9                      Dikson  73.5069   80.5464     27.84        96
#
#    Cloudiness  Wind Speed Country Current Description
# 0          80        5.46      FR       broken clouds
# 1         100        4.45      MM     overcast clouds
# 2          99        3.11      PG     overcast clouds
# 3         100        9.53      ZA     overcast clouds
# 4         100        2.33      RU     overcast clouds
# 5         100       12.30      GB     overcast clouds
# 6          57        7.81      RU       broken clouds
# 7          63        8.01      US       broken clouds
# 8         100        3.53      MX     overcast clouds
# 9         100        6.58      RU     overcast clouds

# %%
#rearrange columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
WeatherPy_df = city_data_df[new_column_order]
WeatherPy_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Vierzon      FR  47.2101    2.0625     64.99        56
# 1         Nyaunglebin      MM  17.9500   96.7333     75.72        95
# 2               Kimbe      PG  -5.5502  150.1429     74.59        92
# 3         Port Alfred      ZA -33.5906   26.8910     59.94        43
# 4     Mnogovershinnyy      RU  53.9353  139.9242     49.06        82
# ..                ...     ...      ...       ...       ...       ...
# 708        Rio Grande      BR -32.0350  -52.0986     51.91        56
# 709           Garissa      KE  -0.4536   39.6401     76.28        76
# 710  Puerto Escondido      MX  15.8500  -97.0667     74.23        68
# 711          Udankudi      IN   8.4333   78.0167     81.43        73
# 712          Berlevag      NO  70.8578   29.0864     48.20        81
#
#      Cloudiness  Wind Speed Current Description
# 0            80        5.46       broken clouds
# 1           100        4.45     overcast clouds
# 2            99        3.11     overcast clouds
# 3           100        9.53     overcast clouds
# 4           100        2.33     overcast clouds
# ..          ...         ...                 ...
# 708          40       15.39    scattered clouds
# 709          34       16.40    scattered clouds
# 710         100        6.91     overcast clouds
# 711         100       11.21     overcast clouds
# 712           0        9.22           clear sky
#
# [713 rows x 9 columns]

# %%
output_data_file="Weather_Database/WeatherPy_Database.csv"
#export the city_data to aa csv
WeatherPy_df.to_csv(output_data_file, index_label="City_ID")
